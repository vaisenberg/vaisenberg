# %%
import matplotlib.pyplot as plt 
fig, ax = plt.subplots()

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.figure()    
plt.plot(x, y)
plt.show()

# %%
import numpy as np
x = np.arange(0, 11) 
y = x ** 2 
plt.figure(figsize=(8, 6))
plt.plot(x, y, marker='o', linestyle='-', color='b', label='y = x^2')

# Adding titles and labels
plt.title('Line Plot of y = x^2', fontsize=14)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)

# Display the plot
plt.show()

# %%
plt.plot(x, y, color='green', linestyle='dashed', linewidth=2, marker='o',
         markerfacecolor='blue', markersize=6)
plt.show()

# %% [markdown]
# lecture on

# %%
categories = ['Apples', 'Bananas', 'Oranges', 'Grapes']
values = [20, 35, 30, 15]

plt.bar(categories, values)
plt.title('Fruit Sales Data')
plt.xlabel('Fruit')
plt.ylabel('Sales')
plt.show()

# %%
data2 = np.random.normal(5, 1.5, 1000)

# Create overlapping histograms
plt.hist(data, bins=30, alpha=0.5, label='Dataset 1', edgecolor='black')
plt.hist(data2, bins=30, alpha=0.5, label='Dataset 2', color='orange', edgecolor='black')
plt.title("Comparing Two Distributions")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 data2 = np.random.normal(5, 1.5, 1000)
#       3 # Create overlapping histograms
# ----> 4 plt.hist(data, bins=30, alpha=0.5, label='Dataset 1', edgecolor='black')
#       5 plt.hist(data2, bins=30, alpha=0.5, label='Dataset 2', color='orange', edgecolor='black')
#       6 plt.title("Comparing Two Distributions")
#
# NameError: name 'data' is not defined
